# %%
from preprocessing import *
from postprocessing import *

# %%
# creates a file that lists all upregulated targets for each pair of conditions (data/product/upregulated_targets.csv)
create_upregulated_targets_file()
# Out:
#         ID                       DOWN_CONDITION--UP_CONDITION
# 0        0                                                NaN
# 1        1            4_1_c--4_4_d;4_1_c--9_7_d;4_1_c--21_2_d
# 2        2  2_4_a--1_1_d;15_6_c--1_1_d;18_6_d--1_1_d;15_6_...
# 3        3                                                NaN
# 4        4                                                NaN
# 5        5                                                NaN
# 6        6                                                NaN
# 7        7                                                NaN
# 8        8                                                NaN
# 9        9                                                NaN
# 10      10                                                NaN
# 11      11                                                NaN
# 12      12  1_1_d--1_4_d;1_1_d--3_4_d;1_1_d--4_3_d;1_1_d--...
# 13      13                                                NaN
# ...

# %%
# creates a mapping of snp transition counts for each gene
# only SNPs within TFs are considered
create_snp_to_gene_file()
# Out:
# Working on SNP: 2599
# Skipped SNP: 2599
# Working on SNP: 2600
# --------------------------------------------------
# Working on SNP: 2601
# Skipped SNP: 2601
# Working on SNP: 2602
# --------------------------------------------------
# Working on SNP: 2603
# --------------------------------------------------
# Working on SNP: 2604
# --------------------------------------------------
# Working on SNP: 2605
# --------------------------------------------------
# Working on SNP: 2606
# Skipped SNP: 2606
# Working on SNP: 2607
# Skipped SNP: 2607
# Working on SNP: 2608
# --------------------------------------------------
# Working on SNP: 2609
# --------------------------------------------------
# Working on SNP: 2610
# --------------------------------------------------
# Working on SNP: 2611
# --------------------------------------------------
# Working on SNP: 25
# Skipped SNP: 25
# Working on SNP: 26
# --------------------------------------------------
# Working on SNP: 27
# ...

# %%
pandas.read_csv('../../../data/product/snp_to_gene.csv')
# Out:
#        SNP_ID  GENE_ID  0--2  0--1  1--2  2--0  1--0  2--1  0--0  1--1  2--2
# 0        2600        1     0     1     0     0     0     0     2     0     0
# 1        2600        2     0     0     0     0   116     0     0   105     0
# 2        2600       12     0   236     0     0    84     0   138   170     0
# 3        2600       19     0     4     0     0    10     0     3    22     0
# 4        2600       23     0     0     1     0    46     0     0    44     0
# 5        2600       26     0    12     2     0    64     0    70    26     0
# 6        2600       28     0    35     0     0    22     0    17    30     0
# 7        2600       29     2    94     2     0    55     0    61    87     0
# 8        2600       32     0     0     0     0     2     0     0     0     0
# 9        2600       35     2    50     0     0     0     0    48     0     0
# 10       2600       39     0     0     0     0     0     0     1     0     0
# ...

# %%
create_annotated_snp_to_gene_table()
# Out:
#        SNP_ID  GENE_ID  0--2  0--1  1--2  2--0  1--0  2--1  0--0  1--1  2--2  \
# 0        2600        1     0     1     0     0     0     0     2     0     0
# 1        2600        2     0     0     0     0   116     0     0   105     0
# 2        2600       12     0   236     0     0    84     0   138   170     0
# 3        2600       19     0     4     0     0    10     0     3    22     0
# 4        2600       23     0     0     1     0    46     0     0    44     0
# 5        2600       26     0    12     2     0    64     0    70    26     0
# 6        2600       28     0    35     0     0    22     0    17    30     0
# 7        2600       29     2    94     2     0    55     0    61    87     0
# 8        2600       32     0     0     0     0     2     0     0     0     0
# 9        2600       35     2    50     0     0     0     0    48     0     0
# 10       2600       39     0     0     0     0     0     0     1     0     0
# ...

# %%
# create the ROC curves for each SNP predictive power
create_SNP_TARGET_ROCs_allele_bias()
